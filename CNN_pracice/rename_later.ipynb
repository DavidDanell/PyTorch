# %%
from pathlib import Path

# %%
from pathlib import Path

DATA_DIR = Path("animal10/raw-img")

print(DATA_DIR.exists())
print(DATA_DIR)
# Out:
# False
# animal10\raw-img

# %%
from pathlib import Path

current_folder = Path.cwd()

print("Jag kör från:")
print(current_folder)

print("\nFiler och mappar här:")
for item in current_folder.iterdir():
    print(item)
# Out:
# Jag kör från:
# c:\Users\David Danell\PyTorch\PyTorch\CNN_pracice
#
# Filer och mappar här:
# c:\Users\David Danell\PyTorch\PyTorch\CNN_pracice\rename_later.ipynb
# c:\Users\David Danell\PyTorch\PyTorch\CNN_pracice\roadmap.ipynb
